# %%
import nibabel
import os
import cv2
import matplotlib.pyplot as plt

# %%
print(os.path.exists('/kaggle/input/brats2023-ssa-training-dataset/ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData_V2/BraTS-SSA-00002-000/BraTS-SSA-00002-000-t1c.nii'))
# Out:
# True

# %%
working_dir = '/kaggle/input/brats2023-ssa-training-dataset/ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData_V2/BraTS-SSA-00002-000/BraTS-SSA-00002-000-t1n.nii'

img = nibabel.load(working_dir)
img

# %%
img_data = img.get_fdata()
img_data.shape
# Out:
# (240, 240, 155)

# %%
slice = img_data[1:, 1:, 86]
print(slice.shape)
plt.imshow(slice, cmap='gray')
# Out:
# (239, 239)
